# %%
import pandas as pd
import numpy as np
df1 = {
    "ID":[1,2,3],
    "Name":["fayyaz","ahsan","azeem"]
}
print()

# %%
df2 = {
    "ID":[1,2,3,4],
    "Name":["fayyaz","ahsan","azeem","ali"]
}
print(df2)
df = pd.merge(df1,df2,on="ID")
print(df)
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ['fayyaz', 'ahsan', 'azeem', 'ali']}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       1 df2 = {
#       2     "ID":[1,2,3,4],
#       3     "Name":["fayyaz","ahsan","azeem","ali"]
#       4 }
#       5 print(df2)
# ----> 6 df = pd.merge(df1,df2,on="ID")
#       7 print(df)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:367, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     145 @set_module("pandas")
#     146 def merge(
#     147     left: DataFrame | Series,
#    (...)    159     validate: str | None = None,
#     160 ) -> DataFrame:
#     161     """
#     162     Merge DataFrame or named Series objects with a database-style join.
#     163
#    (...)    365     3   bar      8
#     366     """
# ...

# %%
import pandas as pd

# %%
a= [10,20,30,40,50]
s=pd.Series(a)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s=pd.Series([10,20,30,40] , index = ['a','b','c','d'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data{
